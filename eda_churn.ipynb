# %%
# !pip install pandas
# Out:
# ^C
# ...
#   Using cached pandas-3.0.6-cp314-cp314-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.5.3-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached tzdata-2026.4-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-3.0.6-cp314-cp314-win_amd64.whl (9.8 MB)
# Using cached numpy-2.5.3-cp314-cp314-win_amd64.whl (12.7 MB)
# Using cached tzdata-2026.4-py2.py3-none-any.whl (347 kB)
# ...
#
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
# ...

# %%
import pandas as pd

# %%
import numpy as np

# %%
read_csv = pd.read_csv('aa.csv')

# %%
pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    --------- ------------------------------ 2.4/9.5 MB 11.9 MB/s eta 0:00:01
#    -------------------- ------------------- 5.0/9.5 MB 11.8 MB/s eta 0:00:01
#    ------------------------------- -------- 7.6/9.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 11.2 MB/s  0:00:00
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ----------------------------- ---------- 1.8/2.5 MB 9.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 9.0 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------- ----------------------------- 1.8/7.2 MB 8.9 MB/s eta 0:00:01
# ...

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
read_csv.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000
